# %%
import w2
df = w2.read_plot_control('plots_CalBase_WholeBasin_MJKirwan_2013.yaml')
df
# Out:
#                         Filename  \
# item
# MET_WB1             2013_Met.npt
# QIN_BR1     2013_WBranch_Qin.npt
# QIN_BR2      2013_Silver_Qin.npt
# QIN_BR3      2013_noname_Qin.npt
# TIN_BR1     2013_WBranch_Tin.npt
# TIN_BR2    2013_WBranch_Tin1.npt
# TIN_BR3    2013_WBranch_Tin2.npt
# CIN_BR1  2013_WBranch_CinEst.npt
# CIN_BR2   2013_Silver_CinEst.npt
# CIN_BR3   2013_noname_CinEst.npt
# QOT_TR1     2013_MJKirwanDam.npt
# QGT         2013_MJKirwanDam.npt
# QTR_TR1      2013_Barrel_Qtr.npt
# QTR_TR2       2013_Bixon_Qtr.npt
# QTR_TR3     2013_Hinkley_Qtr.npt
# TTR_TR1    2013_WBranch_Tin3.npt
# TTR_TR2    2013_WBranch_Tin4.npt
# TTR_TR3    2013_WBranch_Tin5.npt
# CTR_TR1   2013_Barrel_CtrEst.npt
# CTR_TR2    2013_Bixon_CtrEst.npt
# CTR_TR3  2013_Hinkley_CtrEst.npt
# QDT_BR1            2013_Kqwb.npt
# TDT_BR1            2013_Ktdt.npt
# CDT_BR1            2013_Kcdt.npt
# PRE_BR1             2013_Pre.npt
# PRE_BR2            2013_Pre1.npt
# PRE_BR3            2013_Pre2.npt
# ...
