# %% [markdown]
# # Mahoning Watershed CE-QUAL-W2 Model Review for Pittsburgh District, 28Jan2022
#
# ## Models provided by Annett, USGS, 30Nov2021

# %% [markdown]
# ______________________________________________________________
# <h1><font color="orange">
# Individual Year Models
# </font></h1>
# ______________________________________________________________
#
# ## Individual Year Models: BerlinMiltonLakes, 2006

# %%
import w2
year = 2006
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/BerlinMiltonLakes/2006'
plot_control_file = 'plots_IndividualYears_BerlinMilton_2006.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/BerlinMiltonLakes/2006'
plot_control_file = 'plots_IndividualYears_BerlinMilton_2006.yaml'
title = "CE-QUAL-W2 Individual Year Models, Berlin and Milton Lakes Model, 2006"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_BerlinMiltonLakes_2006.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Individual Year Models: BerlinMiltonLakes, 2017

# %%
import w2
year = 2017
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/BerlinMiltonLakes/2017'
plot_control_file = 'plots_IndividualYears_BerlinMilton_2017.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/BerlinMiltonLakes/2017'
plot_control_file = 'plots_IndividualYears_BerlinMilton_2017.yaml'
title = "CE-QUAL-W2 Individual Year Models, Berlin and Milton Lakes Model, 2017"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
display(control_df)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_BerlinMiltonLakes_2017.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Individual Year Models: Mahoning River, 2013

# %%
import w2
year = 2013
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MahoningRiver/2013_WQLeav_WB'
plot_control_file = 'plots_IndividualYears_Mahoning_2013.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MahoningRiver/2013_WQLeav_WB'
plot_control_file = 'plots_IndividualYears_Mahoning_2013.yaml'
title = "CE-QUAL-W2 Individual Year Models, Mahoning River, 2013"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_Mahoning_2013.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Individual Year Models: Mahoning River, 2019
#
# ### Notes
#
# * Error in 2019_qdt_down36.npt:
#     * Julian Day is incorrect. It should be approx. 24.622, but it is "24.6 5" on line 571.
#     * Corrected Julian Day to 24.622

# %%
import w2
year = 2019
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MahoningRiver/2019_WB'
plot_control_file = 'plots_IndividualYears_Mahoning_2019.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MahoningRiver/2019_WB'
title = "CE-QUAL-W2 Individual Year Models, Mahoning River, 2019"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

plot_control_file = 'plots_IndividualYears_Mahoning_2019.yaml'
control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_Mahoning_2019.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Individual Year Models: MJ Kirwan Lake, 2006

# %%
import w2
year = 2006
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MJKirwanLake/2006'
plot_control_file = 'plots_IndividualYears_MJKirwan_2006.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MJKirwanLake/2006'
plot_control_file = 'plots_IndividualYears_MJKirwan_2006.yaml'
title = "CE-QUAL-W2 Individual Year Models, MJ Kirwan Lake, 2006"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_MJKirwan_2006.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Individual Year Models: MJ Kirwan Lake, 2019

# %%
import w2
year = 2019
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MJKirwanLake/2019'
plot_control_file = 'plots_IndividualYears_MJKirwan_2019.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MJKirwanLake/2019'
plot_control_file = 'plots_IndividualYears_MJKirwan_2019.yaml'
title = "CE-QUAL-W2 Individual Year Models, MJ Kirwan Lake, 2019"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_MJKirwan_2019.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Individual Year Models: Mosquito Creek Lake, 2013

# %%
import w2
year = 2013
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MosquitoCreekLake/2013'
plot_control_file = 'plots_IndividualYears_MosquitoCreekLake_2013.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MosquitoCreekLake/2013'
plot_control_file = 'plots_IndividualYears_MosquitoCreekLake_2013.yaml'
title = "CE-QUAL-W2 Individual Year Models, Mosquito Creek Lake, 2013"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_MosquitoCreekLake_2013.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Individual Year Models: Mosquito Creek Lake, 2018

# %%
import w2
year = 2018
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MosquitoCreekLake/2018'
plot_control_file = 'plots_IndividualYears_MosquitoCreekLake_2018.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/Individual_Year_Models/MosquitoCreekLake/2018'
plot_control_file = 'plots_IndividualYears_MosquitoCreekLake_2018.yaml'
title = "CE-QUAL-W2 Individual Year Models, Mosquito Creek Lake, 2018"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Individual_Year_Models_MosquitoCreekLake_2018.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ______________________________________________________________
# <h1><font color="orange">
# Whole Basin and Scenario Models
# </font></h1>
# ______________________________________________________________
#
# ## Whole Basin and Scenario Models: Berlin and Milton Lakes, 2013

# %%
import w2
year = 2013
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_BerlinMilton'
plot_control_file = 'plots_CalBase_WholeBasin_BerlinMilton_2013.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_BerlinMilton'
plot_control_file = 'plots_CalBase_WholeBasin_BerlinMilton_2013.yaml'
title = "CE-QUAL-W2 Whole Basin and Scenario Models, Berlin and Milton Lakes, 2013"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Whole_Basin_and_Scenario_BerlinMilton_2013.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Whole Basin and Scenario Models: MJ Kirwan Lake, 2013

# %%
import w2
year = 2013
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_Kirwan'
plot_control_file = 'plots_CalBase_WholeBasin_MJKirwan_2013.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_Kirwan'
plot_control_file = 'plots_CalBase_WholeBasin_MJKirwan_2013.yaml'
title = "CE-QUAL-W2 Whole Basin and Scenario Models, MJ Kirwan Lake, 2013"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Whole_Basin_and_Scenario_MJKirwan_2013.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import w2
#       2 model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_Kirwan'
#       3 plot_control_file = 'plots_CalBase_WholeBasin_MJKirwan_2013.yaml'
#
# ModuleNotFoundError: No module named 'w2'

# %% [markdown]
# ## Whole Basin and Scenario Models: Mosquito Creek Lake, 2013

# %%
import w2
year = 2013
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_MCLake'
plot_control_file = 'plots_CalBase_WholeBasin_MosquitoCreekLake_2013.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_MCLake'
plot_control_file = 'plots_CalBase_WholeBasin_MosquitoCreekLake_2013.yaml'
title = "CE-QUAL-W2 Whole Basin and Scenario Models, Mosquito Creek Lake, 2013"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Whole_Basin_and_Scenario_MosquitoCreekLake_2013.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Whole Basin and Scenario Models: Mosquito Creek, 2013

# %%
import w2
year = 2013
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_MCreek'
plot_control_file = 'plots_CalBase_WholeBasin_MosquitoCreek_2013.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_MCreek'
plot_control_file = 'plots_CalBase_WholeBasin_MosquitoCreek_2013.yaml'
title = "CE-QUAL-W2 Whole Basin and Scenario Models, Mosquito Creek, 2013"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Whole_Basin_and_Scenario_MosquitoCreek_2013.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)

# %% [markdown]
# ## Whole Basin and Scenario Models: Mahoning River, 2013

# %%
import w2
year = 2013
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_River_WB'
plot_control_file = 'plots_CalBase_WholeBasin_Mahoning_2013.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])

# %% [markdown]
# ### Plot Summary Report

# %%
import w2
model_path = '/Users/todd/Documents/Work/Reviews/Studies/Pittsburgh_District/Mahoning_2022_review/Nov_review_files_from_Annett/WholeBasin_and_Scenario/0_CalBase_WholeBasin/2013_River_WB'
plot_control_file = 'plots_CalBase_WholeBasin_Mahoning_2013.yaml'
title = "CE-QUAL-W2 Whole Basin and Scenario Models, Mahoning River, 2013"
subtitle = "Model Input and Output Data"

yaml = '''---
title: "{title}"
author: Todd Steissberg, ERDC-EL
date: "2022-01-31"
lang: "en"
graphics: true
book: true
classoption: [oneside]
...
'''.format(title=title, subtitle=subtitle)

control_df = w2.read_plot_control(plot_control_file)
w2.generate_plots_report(control_df, model_path, 'Plots_Whole_Basin_and_Scenario_Mahoning_2013.md', title=title, subtitle=subtitle, file_type='pdf', yaml=yaml, pdf_report=True)
